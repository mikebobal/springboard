# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Table of contents
# * [1.1 Intorduction](#1.1_Introduction)
#     * [1.2 Purpose](#1.2_Purpose)
#     * [1.3 Approach](#1.3_Approach)
# * [2.1 Explore the data](#2.1)
#     * [2.2 Removing extra data](#2.2)
# * [3.1 Summary](#3.1_Summary)

# %% [markdown]
# ##### 1.1 Introduction: <a id='1.1_Introduction'></a>

# %% [markdown]
# In order to stay in business, commercial grocery stores must offer prices that are commensurate with competitors, offer deals to entice customers, and accurately predict which products, and the quantity of those products, to keep in stock. These considerations are confounded by the effect of both seasonal and regional trends.
#
# Especially for grocers, the consequences of poor inventory management are dire. Perishable items like fruits and vegetables can rot before selling if they are overstocked. Conversely, many locations do not have the real estate or capability to store overstocked, low-demand items that are not selling. According to Retail Wire, overstocking costs the average retailer 3.2% in lost revenue, while understocking items can cost 4.1%. A review of the data has shown that overstocks are costing retailers \\$123.4 billion every year, and understocks remove another \\$129.5 billion from net inflows. [1]

# %% [markdown]
# ##### 1.2 Purpose<a id='1.2_Purpose'></a>

# %% [markdown]
# Using Kaggle data available from Favorita grocery stores located in Ecuador [2], we will assess and predict sales of available items using time series analysis. There are multiple datasets that will require some data to be merged. We have information on transactions, stores, regions, holidays, and even oil pricing.

# %% [markdown]
# [1] https://www.retailwire.com/discussion/retailers-suffer-the-high-cost-of-overstocks-and-out-of-stocks/
#
# [2] Alexis Cook, DanB, inversion, Ryan Holbrook. (2021). Store Sales - Time Series Forecasting. Kaggle. https://kaggle.com/competitions/store-sales-time-series-forecasting

# %% [markdown]
# ##### 1.3 Approach<a id='1.3_Approach'></a>

# %% [markdown]
# We will use machine learning time series analysis to forecast sales of different types of items across dozens of stores. This will allow Favorita to become more efficient with its distribution of resources, and more likely to attract customers to purchase certain products at certain times. This analysis can also inform the company of the best times to offer discounts, whether to stock up on certain items, and knowledge of general market trends.

# %% [markdown]
# ##### 2.1 Explore the data<a id='2.1'></a>

# %%
# import needed modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
stores = pd.read_csv('./stores.csv')

# %%
stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
# count missing values
missing = pd.concat([stores.isnull().sum(), 100 * stores.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by="count" ,ascending=False)
# Out:
#            count    %
# store_nbr      0  0.0
# city           0  0.0
# state          0  0.0
# type           0  0.0
# cluster        0  0.0

# %%
print("{} clusters\n\n{}".format(len(stores.cluster.unique()),stores.cluster.value_counts()))
# Out:
# 17 clusters
#
# 3     7
# 6     6
# 10    6
# 15    5
# 13    4
# 14    4
# 11    3
# 4     3
# 8     3
# 1     3
# 9     2
# 7     2
# 2     2
# 12    1
# 5     1
# 16    1
# 17    1
# Name: cluster, dtype: int64

# %%
print("{} cities\n\n{}".format(len(stores.city.unique()),stores.city.value_counts()))
# Out:
# 22 cities
#
# Quito            18
# Guayaquil         8
# Cuenca            3
# Santo Domingo     3
# Manta             2
# Latacunga         2
# Machala           2
# Ambato            2
# Quevedo           1
# Esmeraldas        1
# Loja              1
# Libertad          1
# Playas            1
# Daule             1
# Babahoyo          1
# Salinas           1
# Puyo              1
# Guaranda          1
# Ibarra            1
# Riobamba          1
# Cayambe           1
# El Carmen         1
# Name: city, dtype: int64

# %%
print("{} types\n\n{}".format(len(stores.type.unique()),stores.type.value_counts()))
# Out:
# 5 types
#
# D    18
# C    15
# A     9
# B     8
# E     4
# Name: type, dtype: int64

# %%
print("{} states\n\n{}".format(len(stores.state.unique()),stores.state.value_counts()))
# Out:
# 16 states
#
# Pichincha                         19
# Guayas                            11
# Santo Domingo de los Tsachilas     3
# Azuay                              3
# Manabi                             3
# Cotopaxi                           2
# Tungurahua                         2
# Los Rios                           2
# El Oro                             2
# Chimborazo                         1
# Imbabura                           1
# Bolivar                            1
# Pastaza                            1
# Santa Elena                        1
# Loja                               1
# Esmeraldas                         1
# Name: state, dtype: int64

# %%
holidays = pd.read_csv('./holidays_events.csv')

# %%
holidays.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
holidays.rename(columns={'type':'holiday_type'},inplace=True)

# %%
holidays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          350 non-null    object
#  1   holiday_type  350 non-null    object
#  2   locale        350 non-null    object
#  3   locale_name   350 non-null    object
#  4   description   350 non-null    object
#  5   transferred   350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
holidays["date"] = pd.to_datetime(holidays["date"])

# %%
# count missing values
missing = pd.concat([holidays.isnull().sum(), 100 * holidays.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by="count" ,ascending=False)
# Out:
#               count    %
# date              0  0.0
# holiday_type      0  0.0
# locale            0  0.0
# locale_name       0  0.0
# description       0  0.0
# transferred       0  0.0

# %%
print("{} holiday types\n\n{}".format(len(holidays.holiday_type.unique()),holidays.holiday_type.value_counts()))
# Out:
# 6 holiday types
#
# Holiday       221
# Event          56
# Additional     51
# Transfer       12
# Bridge          5
# Work Day        5
# Name: holiday_type, dtype: int64

# %%
print("{} locales\n\n{}".format(len(holidays.locale.unique()),holidays.locale.value_counts()))
# Out:
# 3 locales
#
# National    174
# Local       152
# Regional     24
# Name: locale, dtype: int64

# %%
print("{} locale names\n\n{}".format(len(holidays.locale_name.unique()),holidays.locale_name.value_counts()))
# Out:
# 24 locale names
#
# Ecuador                           174
# Quito                              13
# Riobamba                           12
# Guaranda                           12
# Latacunga                          12
# Ambato                             12
# Guayaquil                          11
# Cuenca                              7
# Ibarra                              7
# Salinas                             6
# Loja                                6
# Santa Elena                         6
# Santo Domingo de los Tsachilas      6
# Quevedo                             6
# Manta                               6
# Esmeraldas                          6
# Cotopaxi                            6
# El Carmen                           6
# Santo Domingo                       6
# Machala                             6
# Imbabura                            6
# Puyo                                6
# Libertad                            6
# Cayambe                             6
# Name: locale_name, dtype: int64

# %% [markdown]
# There appears to be a mix of City, State, and Country locale names here.

# %%
list(holidays[holidays.locale == "Local"].locale_name.unique())
# Out:
# ['Manta',
#  'Cuenca',
#  'Libertad',
#  'Riobamba',
#  'Puyo',
#  'Guaranda',
#  'Latacunga',
#  'Machala',
#  'Santo Domingo',
#  'El Carmen',
#  'Cayambe',
#  'Esmeraldas',
#  'Ambato',
#  'Ibarra',
#  'Quevedo',
#  'Quito',
#  'Loja',
#  'Salinas',
#  'Guayaquil']

# %% [markdown]
# "Local" locale refers to a city holiday.

# %%
list(holidays[holidays.locale == "Regional"].locale_name.unique())
# Out:
# ['Cotopaxi', 'Imbabura', 'Santo Domingo de los Tsachilas', 'Santa Elena']

# %% [markdown]
# "Regional" locale refers to a state (province) holiday

# %%
list(holidays[holidays.locale == "National"].locale_name.unique())
# Out:
# ['Ecuador']

# %% [markdown]
# Logically, all "National" holidays are of the country locale of Ecuador.

# %% [markdown]
# Therefore, we can make new dataframes for each type of locale, for use later when merging

# %%
local_holiday = holidays[holidays.locale == "Local"]
regional_holiday = holidays[holidays.locale == "Regional"]
national_holiday = holidays[holidays.locale == "National"]

# %%
print("{} descriptions\n\n".format(len(holidays.description.unique())))
# Out:
# 103 descriptions

# %%
print("{} transfer outcomes\n\n{}".format(len(holidays.transferred.unique()),holidays.transferred.value_counts()))
# Out:
# 2 transfer outcomes
#
# False    338
# True      12
# Name: transferred, dtype: int64

# %%
transactions = pd.read_csv('./transactions.csv')

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions["date"] = pd.to_datetime(transactions["date"])

# %%
transactions.transactions.describe()
# Out:
# count    83488.000000
# mean      1694.602158
# std        963.286644
# min          5.000000
# 25%       1046.000000
# 50%       1393.000000
# 75%       2079.000000
# max       8359.000000
# Name: transactions, dtype: float64

# %%
missing = pd.concat([transactions.isnull().sum(), 100 * transactions.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by="count" ,ascending=False)
# Out:
#               count    %
# date              0  0.0
# store_nbr         0  0.0
# transactions      0  0.0

# %%
print("{} stores\n\n{}".format(len(transactions.store_nbr.unique()),transactions.store_nbr.value_counts()))
# Out:
# 54 stores
#
# 39    1678
# 38    1678
# 26    1678
# 31    1678
# 33    1678
# 34    1678
# 37    1678
# 27    1677
# 28    1677
# 32    1677
# 23    1677
# 40    1677
# 41    1677
# 44    1677
# 45    1677
# 46    1677
# 47    1677
# 48    1677
# 50    1677
# 51    1677
# 49    1677
# 2     1677
# 16    1677
# 5     1677
# 54    1676
# 3     1676
# 4     1676
# 6     1676
# 8     1676
# 9     1676
# 19    1676
# 35    1676
# 13    1676
# 1     1676
# 15    1676
# 11    1676
# 10    1675
# 7     1675
# 17    1674
# 43    1672
# 30    1655
# 14    1638
# 12    1616
# 25    1615
# 24    1577
# 18    1566
# 36    1551
# 53    1167
# 20     909
# 29     874
# 21     748
# 42     720
# 22     671
# 52     118
# Name: store_nbr, dtype: int64

# %%
oil = pd.read_csv('./oil.csv')

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.describe()
# Out:
#         dcoilwtico
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %%
missing = pd.concat([oil.isnull().sum(), 100 * oil.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by="count" ,ascending=False)
# Out:
#             count         %
# dcoilwtico     43  3.530378
# date            0  0.000000

# %%
train_csv = pd.read_csv('./train.csv')

# %%
train_csv.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
missing = pd.concat([train_csv.isnull().sum(), 100 * train_csv.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by="count" ,ascending=False)
# Out:
#              count    %
# id               0  0.0
# date             0  0.0
# store_nbr        0  0.0
# family           0  0.0
# sales            0  0.0
# onpromotion      0  0.0

# %%
train_csv.dtypes
# Out:
# id               int64
# date            object
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object

# %%
train_csv["date"] = pd.to_datetime(train_csv["date"])
train_csv.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# store_nbr               int64
# family                 object
# sales                 float64
# onpromotion             int64
# dtype: object

# %%
train_df = train_csv.set_index('date')

# %%
train_df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion
# date
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# ...                 ...
# 2017-08-15            0
# 2017-08-15            1
# 2017-08-15          148
# 2017-08-15            8
# 2017-08-15            0
#
# [3000888 rows x 5 columns]

# %%
print("{} product families\n\n{}".format(len(train_df.family.unique()),train_df.family.value_counts()))
# Out:
# 33 product families
#
# AUTOMOTIVE                    90936
# HOME APPLIANCES               90936
# SCHOOL AND OFFICE SUPPLIES    90936
# PRODUCE                       90936
# PREPARED FOODS                90936
# POULTRY                       90936
# PLAYERS AND ELECTRONICS       90936
# PET SUPPLIES                  90936
# PERSONAL CARE                 90936
# MEATS                         90936
# MAGAZINES                     90936
# LIQUOR,WINE,BEER              90936
# LINGERIE                      90936
# LAWN AND GARDEN               90936
# LADIESWEAR                    90936
# HOME CARE                     90936
# HOME AND KITCHEN II           90936
# BABY CARE                     90936
# HOME AND KITCHEN I            90936
# HARDWARE                      90936
# GROCERY II                    90936
# GROCERY I                     90936
# FROZEN FOODS                  90936
# EGGS                          90936
# DELI                          90936
# DAIRY                         90936
# CLEANING                      90936
# CELEBRATION                   90936
# BREAD/BAKERY                  90936
# BOOKS                         90936
# BEVERAGES                     90936
# BEAUTY                        90936
# SEAFOOD                       90936
# Name: family, dtype: int64

# %%
print("{} promotion types\n\n{}".format(len(train_df.onpromotion.unique()),train_df.onpromotion.value_counts()))
# Out:
# 362 promotion types
#
# 0      2389559
# 1       174551
# 2        79386
# 3        45862
# 4        31659
#         ...
# 313          1
# 452          1
# 642          1
# 305          1
# 425          1
# Name: onpromotion, Length: 362, dtype: int64

# %%
train_df.sales.describe()
# Out:
# count    3.000888e+06
# mean     3.577757e+02
# std      1.101998e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.100000e+01
# 75%      1.958473e+02
# max      1.247170e+05
# Name: sales, dtype: float64

# %% [markdown]
# Make list of unique "family" names

# %%
family_values = train_df.family.unique()

# %% [markdown]
# Make a list of all unique store numbers

# %%
store_id = train_df.store_nbr.unique()

# %% [markdown]
# Now we can start to combine all of the pertinent columns from the various dataframes

# %%
train_csv
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]

# %% [markdown]
# First, we combine the train_csv sales data with geographical store information

# %%
store_info_1 = train_csv.merge(stores,on=['store_nbr'],how='left')
store_info_1
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state type  cluster
# 0                  0  Quito  Pichincha    D       13
# 1                  0  Quito  Pichincha    D       13
# 2                  0  Quito  Pichincha    D       13
# 3                  0  Quito  Pichincha    D       13
# 4                  0  Quito  Pichincha    D       13
# ...              ...    ...        ...  ...      ...
# 3000883            0  Quito  Pichincha    B        6
# 3000884            1  Quito  Pichincha    B        6
# 3000885          148  Quito  Pichincha    B        6
# 3000886            8  Quito  Pichincha    B        6
# 3000887            0  Quito  Pichincha    B        6
#
# [3000888 rows x 10 columns]

# %% [markdown]
# Next, we combine the prior dataframe with holiday information; local first.

# %%
lh = local_holiday[local_holiday.transferred==False]

# %%
store_info_2 = store_info_1.merge(lh,how='left',right_on=['locale_name','date'],
                                  left_on=['city','date']).drop(['locale_name','description'], axis=1)

# .drop_duplicates(['date','store_nbr','family']).reset_index()
store_info_2
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3001147  3000883 2017-08-15          9                     POULTRY   438.133
# 3001148  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3001149  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3001150  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3001151  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state type  cluster holiday_type locale  \
# 0                  0  Quito  Pichincha    D       13          NaN    NaN
# 1                  0  Quito  Pichincha    D       13          NaN    NaN
# 2                  0  Quito  Pichincha    D       13          NaN    NaN
# 3                  0  Quito  Pichincha    D       13          NaN    NaN
# 4                  0  Quito  Pichincha    D       13          NaN    NaN
# ...              ...    ...        ...  ...      ...          ...    ...
# 3001147            0  Quito  Pichincha    B        6          NaN    NaN
# 3001148            1  Quito  Pichincha    B        6          NaN    NaN
# 3001149          148  Quito  Pichincha    B        6          NaN    NaN
# 3001150            8  Quito  Pichincha    B        6          NaN    NaN
# 3001151            0  Quito  Pichincha    B        6          NaN    NaN
#
#         transferred
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3001147         NaN
# 3001148         NaN
# 3001149         NaN
# 3001150         NaN
# 3001151         NaN
#
# [3001152 rows x 13 columns]

# %% [markdown]
# Unfortunately, there are more rows in the new dataframe than the prior one. We need to investigate and correct this issue.

# %% [markdown]
# Since the prior and new dataframes both start and end on the same 'id', there must be dates where the holiday dataframe assigns multiple values.

# %% [markdown]
# We make a list of 'id's that appear more than once in the new dataframe.

# %%
test = store_info_2.id.value_counts() > 1
test
# Out:
# 2312781     True
# 2312104     True
# 2312096     True
# 2312097     True
# 2312098     True
#            ...
# 1000298    False
# 1000299    False
# 1000300    False
# 1000301    False
# 3000887    False
# Name: id, Length: 3000888, dtype: bool

# %% [markdown]
# Contracting the dataframe into only unique values and their number of occurrances has reduced the length of the dataframe to the original size (3,000,888 rows).

# %%
test2 = pd.DataFrame(store_info_2[(store_info_2.date > '2012-01-01') & (store_info_2.id.value_counts() > 1)])
test2.date.value_counts()
# Out:
# 2016-07-24    264
# Name: date, dtype: int64

# %% [markdown]
# It appears that on a single date, we have 264 instances of multiple holidays assigned to a single date.

# %%
test2[(test2.date == '2016-07-24') & (test2.id.value_counts() > 1)]
# Out:
# C:\Users\Joseph Shire\AppData\Local\Temp\ipykernel_6764\1028663461.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test2[(test2.date == '2016-07-24') & (test2.id.value_counts() > 1)]
#               id       date  store_nbr            family    sales  \
# 2311782  2311782 2016-07-24         24        AUTOMOTIVE    2.000
# 2311783  2311782 2016-07-24         24        AUTOMOTIVE    2.000
# 2311784  2311783 2016-07-24         24         BABY CARE    1.000
# 2311785  2311783 2016-07-24         24         BABY CARE    1.000
# 2311786  2311784 2016-07-24         24            BEAUTY    6.000
# ...          ...        ...        ...               ...      ...
# 2312024  2311936 2016-07-24         28  LIQUOR,WINE,BEER  640.000
# 2312025  2311936 2016-07-24         28  LIQUOR,WINE,BEER  640.000
# 2312026  2311937 2016-07-24         28         MAGAZINES    2.000
# 2312027  2311937 2016-07-24         28         MAGAZINES    2.000
# 2312028  2311938 2016-07-24         28             MEATS  227.947
#
#          onpromotion       city   state type  cluster holiday_type locale  \
# 2311782            0  Guayaquil  Guayas    D        1   Additional  Local
# 2311783            0  Guayaquil  Guayas    D        1     Transfer  Local
# 2311784            0  Guayaquil  Guayas    D        1   Additional  Local
# 2311785            0  Guayaquil  Guayas    D        1     Transfer  Local
# 2311786            1  Guayaquil  Guayas    D        1   Additional  Local
# ...              ...        ...     ...  ...      ...          ...    ...
# 2312024            0  Guayaquil  Guayas    E       10   Additional  Local
# 2312025            0  Guayaquil  Guayas    E       10     Transfer  Local
# 2312026            0  Guayaquil  Guayas    E       10   Additional  Local
# 2312027            0  Guayaquil  Guayas    E       10     Transfer  Local
# 2312028            1  Guayaquil  Guayas    E       10   Additional  Local
#
#         transferred
# 2311782       False
# 2311783       False
# 2311784       False
# 2311785       False
# 2311786       False
# ...             ...
# 2312024       False
# 2312025       False
# 2312026       False
# 2312027       False
# 2312028       False
#
# [80 rows x 13 columns]

# %% [markdown]
# According to documentation,
#
# "A holiday that is transferred officially falls on that calendar day, but was moved to another date by the government. A transferred day is more like a normal day than a holiday...
#
# Additional holidays are days added a regular calendar holiday, for example, as typically happens around Christmas (making Christmas Eve a holiday)."

# %% [markdown]
# The issue is that Simón Bolívar Day falls on 07/24 every year, so it cannot be a transfer to that date.

# %% [markdown]
# Therefore, we will eliminate the rows on 2016-07-24 that are categorized as "Transfer"

# %%
local_holiday2 = local_holiday[local_holiday['holiday_type'].str.contains("Transfer")==False]

# %%
lh2 = local_holiday2[local_holiday2.transferred==False]

# %%
store_info_2b = store_info_1.merge(lh2,how='left',right_on=['locale_name','date'],
                                  left_on=['city','date']).drop(['locale_name','description'], axis=1)

store_info_2b
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state type  cluster holiday_type locale  \
# 0                  0  Quito  Pichincha    D       13          NaN    NaN
# 1                  0  Quito  Pichincha    D       13          NaN    NaN
# 2                  0  Quito  Pichincha    D       13          NaN    NaN
# 3                  0  Quito  Pichincha    D       13          NaN    NaN
# 4                  0  Quito  Pichincha    D       13          NaN    NaN
# ...              ...    ...        ...  ...      ...          ...    ...
# 3000883            0  Quito  Pichincha    B        6          NaN    NaN
# 3000884            1  Quito  Pichincha    B        6          NaN    NaN
# 3000885          148  Quito  Pichincha    B        6          NaN    NaN
# 3000886            8  Quito  Pichincha    B        6          NaN    NaN
# 3000887            0  Quito  Pichincha    B        6          NaN    NaN
#
#         transferred
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3000883         NaN
# 3000884         NaN
# 3000885         NaN
# 3000886         NaN
# 3000887         NaN
#
# [3000888 rows x 13 columns]

# %% [markdown]
# Now we have the correct dataframe size, so we can continue by merging the regional holidays.

# %%
store_info_3 = store_info_2b.merge(regional_holiday,how='left',right_on=['locale_name','date'],
                                  left_on=['state','date']).drop(['locale_name','description'], axis=1)

store_info_3
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state type  cluster holiday_type_x locale_x  \
# 0                  0  Quito  Pichincha    D       13            NaN      NaN
# 1                  0  Quito  Pichincha    D       13            NaN      NaN
# 2                  0  Quito  Pichincha    D       13            NaN      NaN
# 3                  0  Quito  Pichincha    D       13            NaN      NaN
# 4                  0  Quito  Pichincha    D       13            NaN      NaN
# ...              ...    ...        ...  ...      ...            ...      ...
# 3000883            0  Quito  Pichincha    B        6            NaN      NaN
# 3000884            1  Quito  Pichincha    B        6            NaN      NaN
# 3000885          148  Quito  Pichincha    B        6            NaN      NaN
# 3000886            8  Quito  Pichincha    B        6            NaN      NaN
# 3000887            0  Quito  Pichincha    B        6            NaN      NaN
#
#         transferred_x holiday_type_y locale_y transferred_y
# 0                 NaN            NaN      NaN           NaN
# 1                 NaN            NaN      NaN           NaN
# 2                 NaN            NaN      NaN           NaN
# 3                 NaN            NaN      NaN           NaN
# 4                 NaN            NaN      NaN           NaN
# ...               ...            ...      ...           ...
# 3000883           NaN            NaN      NaN           NaN
# 3000884           NaN            NaN      NaN           NaN
# 3000885           NaN            NaN      NaN           NaN
# 3000886           NaN            NaN      NaN           NaN
# 3000887           NaN            NaN      NaN           NaN
#
# [3000888 rows x 16 columns]

# %%
national_holiday
# Out:
#           date holiday_type    locale locale_name  \
# 14  2012-08-10      Holiday  National     Ecuador
# 19  2012-10-09      Holiday  National     Ecuador
# 20  2012-10-12     Transfer  National     Ecuador
# 21  2012-11-02      Holiday  National     Ecuador
# 22  2012-11-03      Holiday  National     Ecuador
# ..         ...          ...       ...         ...
# 345 2017-12-22   Additional  National     Ecuador
# 346 2017-12-23   Additional  National     Ecuador
# 347 2017-12-24   Additional  National     Ecuador
# 348 2017-12-25      Holiday  National     Ecuador
# 349 2017-12-26   Additional  National     Ecuador
#
#                              description  transferred
# 14         Primer Grito de Independencia        False
# 19            Independencia de Guayaquil         True
# 20   Traslado Independencia de Guayaquil        False
# 21                       Dia de Difuntos        False
# 22               Independencia de Cuenca        False
# ..                                   ...          ...
# 345                            Navidad-3        False
# 346                            Navidad-2        False
# 347                            Navidad-1        False
# 348                              Navidad        False
# 349                            Navidad+1        False
#
# [174 rows x 6 columns]

# %%
nh_count = national_holiday.date.value_counts()

# %%
nh_count[nh_count>1].index
# Out:
# DatetimeIndex(['2012-12-31', '2014-12-26', '2016-05-08', '2016-05-07',
#                '2012-12-24', '2016-05-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
national_holiday[national_holiday.date.isin(nh_count[nh_count>1].index)]
# Out:
#           date holiday_type    locale locale_name                description  \
# 35  2012-12-24       Bridge  National     Ecuador             Puente Navidad
# 36  2012-12-24   Additional  National     Ecuador                  Navidad-1
# 39  2012-12-31       Bridge  National     Ecuador  Puente Primer dia del ano
# 40  2012-12-31   Additional  National     Ecuador       Primer dia del ano-1
# 156 2014-12-26       Bridge  National     Ecuador             Puente Navidad
# 157 2014-12-26   Additional  National     Ecuador                  Navidad+1
# 235 2016-05-01      Holiday  National     Ecuador            Dia del Trabajo
# 236 2016-05-01        Event  National     Ecuador        Terremoto Manabi+15
# 242 2016-05-07   Additional  National     Ecuador          Dia de la Madre-1
# 243 2016-05-07        Event  National     Ecuador        Terremoto Manabi+21
# 244 2016-05-08        Event  National     Ecuador        Terremoto Manabi+22
# 245 2016-05-08        Event  National     Ecuador            Dia de la Madre
#
#      transferred
# 35         False
# 36         False
# 39         False
# 40         False
# 156        False
# 157        False
# 235        False
# 236        False
# 242        False
# 243        False
# 244        False
# 245        False

# %%
nh_not_trans = national_holiday[national_holiday.transferred!=True]

# %%
nh_dates = nh_not_trans.date.unique()

# %%
store_info_3["national_holiday"] = store_info_3.date.isin(nh_dates)

# %%
store_info_3
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state type  cluster holiday_type_x locale_x  \
# 0                  0  Quito  Pichincha    D       13            NaN      NaN
# 1                  0  Quito  Pichincha    D       13            NaN      NaN
# 2                  0  Quito  Pichincha    D       13            NaN      NaN
# 3                  0  Quito  Pichincha    D       13            NaN      NaN
# 4                  0  Quito  Pichincha    D       13            NaN      NaN
# ...              ...    ...        ...  ...      ...            ...      ...
# 3000883            0  Quito  Pichincha    B        6            NaN      NaN
# 3000884            1  Quito  Pichincha    B        6            NaN      NaN
# 3000885          148  Quito  Pichincha    B        6            NaN      NaN
# 3000886            8  Quito  Pichincha    B        6            NaN      NaN
# 3000887            0  Quito  Pichincha    B        6            NaN      NaN
#
#         transferred_x holiday_type_y locale_y transferred_y  national_holiday
# 0                 NaN            NaN      NaN           NaN              True
# 1                 NaN            NaN      NaN           NaN              True
# 2                 NaN            NaN      NaN           NaN              True
# 3                 NaN            NaN      NaN           NaN              True
# 4                 NaN            NaN      NaN           NaN              True
# ...               ...            ...      ...           ...               ...
# 3000883           NaN            NaN      NaN           NaN             False
# 3000884           NaN            NaN      NaN           NaN             False
# 3000885           NaN            NaN      NaN           NaN             False
# 3000886           NaN            NaN      NaN           NaN             False
# 3000887           NaN            NaN      NaN           NaN             False
#
# [3000888 rows x 17 columns]

# %% [markdown]
# We have run into another duplicate rows issue.

# %% [markdown]
# ##### 2.2 Removing extra data<a id='2.2'></a>

# %% [markdown]
# We export the finalized data for future use as a .csv file

# %%
f = 
ctg.to_csv(f)

# %% [markdown]
# ##### 3.1 Summary<a id='3.1_Summary'></a>

# %% [markdown]
# The data was loaded, inspected, cleaned, saved, and is now ready for exploratory data analysis. There are no more missing values, and the only columns still in the dataset are necessary for proper classification modelling.

# %% [markdown]
# The next step (in a different notebook) will be exploratory data analysis. Already, it appears that we will need to use dummy encoding (pandas 'get_dummies' method) in order to transform our categorical NSP target into '0 or 1' variables comprising 3 columns (one for each outcome possibility: N, S, or P).
